# %%
# Add imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set up dataframes
df1 = pd.read_csv('data/Travel_titles_validations_in_Paris_and_suburbs.csv')
df2 = pd.read_csv('data/Regularities_by_liaisons_Trains_France.csv')

# %%
# Data exploration
df1.head()
df1.info()
df1.describe()

df2.head()
df2.info()
df2.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883958 entries, 0 to 883957
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DATE            883958 non-null  object
#  1   STATION_NAME    883958 non-null  object
#  2   ID_REFA_LDA     882459 non-null  float64
#  3   TITLE_CATEGORY  883958 non-null  object
#  4   NB_VALID        883958 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 33.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7806 entries, 0 to 7805
# Data columns (total 32 columns):
#  #   Column                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                               --------------  -----
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df2['Average travel time (min)'], bins=30, kde=True)
plt.title('Distribution of Average Travel Times')
plt.xlabel('Average Travel Time (Minutes)')
plt.ylabel('Frequency')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plotting Number of Late Trains
plt.figure(figsize=(10, 6))
sns.boxplot(x=df2['Number of late trains at departure'])
plt.title('Boxplot of Number of Late Trains at Departure')
plt.xlabel('Number of Late Trains')
plt.show()

# Plotting Number of Cancelled Trains
plt.figure(figsize=(10, 6))
sns.boxplot(x=df2['Number of cancelled trains'])
plt.title('Boxplot of Number of Cancelled Trains')
plt.xlabel('Number of Cancelled Trains')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Aggregating Data by Route
route_delays = df2.groupby('Departure station')['Average delay of all departing trains (min)'].mean().reset_index()

# Plotting Average Delay by Route
plt.figure(figsize=(12, 8))
sns.barplot(x='Average delay of all departing trains (min)', y='Departure station', data=route_delays.sort_values(by='Average delay of all departing trains (min)', ascending=False))
plt.title('Average Delay by Departure Station')
plt.xlabel('Average Delay (Minutes)')
plt.ylabel('Departure Station')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
numeric_df2 = df2.select_dtypes(include=[np.number])

correlation_matrix = numeric_df2.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

X_cleaned = X.dropna()

from sklearn.impute import SimpleImputer

# Impute missing values with the mean
imputer = SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)


# Standardizing the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_cleaned)

# %%
from sklearn.cluster import KMeans

# Using the Elbow Method to determine k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    sse.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), sse, marker='o')
plt.title('Elbow Method for Determining k')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/threadpoolctl.py:1019: RuntimeWarning: libc not found. The ctypes module in Python 3.9 is maybe too old for this OS.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Apply K-means with the chosen number of clusters
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# Add the cluster labels to the original dataframe
df2['Cluster'] = clusters

# Analyzing the clusters
clustered_data = df2.groupby('Cluster').mean()
print(clustered_data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/zackwilson/France-Public-Transport-Clustering/Notebook.ipynb Cell 10 line 7
#       <a href='vscode-notebook-cell:/Users/zackwilson/France-Public-Transport-Clustering/Notebook.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> clusters = kmeans.fit_predict(X_scaled)
#       <a href='vscode-notebook-cell:/Users/zackwilson/France-Public-Transport-Clustering/Notebook.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a> # Add the cluster labels to the original dataframe
# ...
